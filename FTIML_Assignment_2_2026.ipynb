# %% [markdown]
# # FTIML Assignment 2: Fairness (10 points)
#
# ## Dataset: 2021 British Columnbia (Canada) Census data
#
# The dataset represents the 2021 British Columbia (Canada) Census data. Each row describes the demographic and socioeconomic characteristics of an individual. The objective is to predict whether an individual's income exceeds 75K. These predictions will be used by a company that determines loan approvals based on your model's output. An individual's income may be influenced by their demographic and socioeconomic attributes. However, the company is legally prohibited from engaging in unfair treatment on the basis of "race, national or ethnic origin, colour, religion, age, sex, sexual orientation, gender identity or expression, marital status, family status, genetic characteristics, disability, or conviction for an offence for which a pardon has been granted or in respect of which a record suspension has been ordered", as outlined in the Canadian Human Rights Act. Your task is to analyze the fairness of your model's predictions and to apply techniques to improve the fairness of your models.
#
# See for more information on the dataset "2021 Census Individuals PUMF User Guide.pdf". You are not required to read the entire document.
#
# Hint: Unavailable data is often encoded by 88888888 or 99999999.
#
# ## Deliverable:
#
# A **.zip file** containing two elements:
# 1. The **Jupyter notebook** you used for your analysis of Tasks a - d below (in ipynb).
# 2. A **report of max. 4 pages** with the complete answers to the questions below (in pdf).
#
# **DEADLINE: Monday May 11, 2026 at 23:59.**
#
# Note: All information in 2. needs to be contained in 1. (not necessarily vice versa).
#
# Note: The grade for the assignment is primarily based on your presentation on May 12 and your report. The notebook serves as an add-on.
#
#
# ## Task a: Data Exploration
# Before entering the analysis, spend some time to understand the data.
#
# * Which features do you expect to influence fairness?
# * Define groups based on the sensitive feature(s) and visualize the data.
# * Are there any inbalances? How might these affect your fairness analysis?
#
# Use graphs and/or tables, and write down your observations.
#
#
# ## Task b: Explore Fairness
# Take the outcomes of a black-box model (you may use the random forest model fitted below or for example a XGBoost model, neural network, ...) and an interpretable model of your choice and analyze their fairness across different protected groups.
#
# *   Choose and report three group fairness metrics that are useful for the given context and report them.
# *   Do you find evidence for biases in the models? Which group(s) appear to be at a disadvantage?
# *   Are there any differences in fairness metrics between the black-box and interpretable models?
#
# Use visualizations to support your analysis. Summarize the results in text.
#
#
# ## Task c: Individual Fairness
# Try to improve the fairness of your models using two individual fairness techniques.
#
# Refer to the lecture slides and the notebook from the fairness tutorial for guidance on what is expected here.
#
# Clearly state the techniques you are using and elaborate on their effects on the fairness of the models.
#
#
# ## Task d: Group Fairness
# Try to improve the fairness metrics of your models using two group fairness techniques.
#
# Explain why you choose the techniques you are using and elaborate on their effects on the fairness of the models.

# %% [markdown]
# # Preparations

# %% [markdown]
# ## Install and load libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_curve, roc_auc_score, classification_report
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# ## Load and preprocess data
# **Do not change this part**

# %%
data = pd.read_csv('data_donnees_2021_ind_BC.csv')
# print columns all column s
print(list(data.columns))
# Out:
# ['PPSORT', 'ABOID', 'AGEGRP', 'AGEIMM', 'ATTSCH', 'BFNMEMB', 'BEDRM', 'CFSTAT', 'CHDBN', 'CIP2021', 'CIP2021_STEM_SUM', 'CMA', 'CONDO', 'COVID_ERB', 'COW', 'CQPPB', 'CfSize', 'ChldC', 'CitOth', 'Citizen', 'DIST', 'DPGRSUM', 'DTYPE', 'EFDecile', 'EFInc', 'EFInc_AT', 'EICBN', 'ETHDER', 'EfDIMBM_2018', 'EfSize', 'FOL', 'FPTWK', 'Gender', 'GENSTAT', 'GTRfs', 'HCORENEED_IND', 'HDGREE', 'HHSIZE', 'HHTYPE', 'HLMOSTEN', 'HLMOSTFR', 'HLMOSTNO', 'HLREGEN', 'HLREGFR', 'HLREGNO', 'IMMCAT5', 'IMMSTAT', 'JOBPERM', 'KOL', 'LFACT', 'LICO_BT', 'LICO_AT', 'LIPROGTYPE', 'LI_ELIG_OML_U18', 'LOCSTUD', 'LOC_ST_RES', 'LSTWRK', 'LWMOSTEN', 'LWMOSTFR', 'LWMOSTNO', 'LWREGEN', 'LWREGFR', 'LWREGNO', 'LoLIMA', 'LoLIMB', 'LOMBM_2018', 'MODE', 'MTNEn', 'MTNFr', 'MTNNO', 'MARSTH', 'Mob1', 'Mob5', 'NAICS', 'NOC21', 'NOS', 'OASGI', 'PKID25', 'PKID0_1', 'PKID15_24', 'PKID2_5', 'PKID6_14', 'PKIDS', 'POB', 'POBPAR1', 'POBPAR2', 'POWST', 'PR1', 'PR5', 'PRESMORTG', 'PRIHM', 'PWDUR', 'PWLEAVE', 'PWOCC', 'PWPR', 'REGIND', 'RELIGION_DER', 'REPAIR', 'ROOM', 'SHELCO', 'SSGRAD', 'SUBSIDY', 'TENUR', 'VISMIN', 'Value', 'WKSWRK', 'WRKACT', 'YRIMM', 'WEIGHT', 'WT1', 'WT2', 'WT3', 'WT4', 'WT5', 'WT6', 'WT7', 'WT8', 'WT9', 'WT10', 'WT11', 'WT12', 'WT13', 'WT14', 'WT15', 'WT16', '75k']

# %%
# Remove identifiers and weights
drop_cols = ['PPSORT'] + ['WEIGHT'] + [f'WT{i}' for i in range(1, 17)]

# all variables directly derived from income, possible issue
leakage_cols = ['LICO_BT', 'LICO_AT', 'LoLIMA', 'LoLIMB', 'LIPROGTYPE', 
                'LI_ELIG_OML_U18', 'EFInc', 'EFInc_AT', 'EFDecile']

# Sensitive attributes
sensitive_cols = ['AGEGRP', 'Gender', 'VISMIN', 'RELIGION_DER', 
                  'IMMSTAT', 'ABOID', 'MARSTH']

# data = data.drop(columns=drop_cols + leakage_cols)
data = data.drop(columns=drop_cols)

# %%
# fixing all 88888888 to the mean/ mode and 999999999 to -1
data.replace(88888888, np.nan, inplace=True)
data.replace(99999999, -1, inplace=True)

# Identify column types
exclude = ["SHELCO", "75k"] # non categorical variables
cat_cols = [col for col in data.columns if data[col].nunique() < 60 and col not in exclude]
num_cols = [col for col in data.columns if col not in cat_cols]

# all categorical features use 8, 88, or 888 for unavailable data
def get_sentinel(col_max, num_str):
    for sentinel in [int(num_str), int(num_str*2), int(num_str*3), int(num_str*4)]:
        if sentinel >= col_max:
            return sentinel
    return None

for col in cat_cols:
    col_max = data[col].max()
    sentinel = get_sentinel(col_max, "9")
    if sentinel is not None and (data[col] == sentinel).any():
        print(f"{col}: max={col_max}, replacing {sentinel} with -1")
        data[col] = data[col].replace(sentinel, -1)

    col_max = data[col].max()
    sentinel = get_sentinel(col_max, "8")
    if sentinel is not None and (data[col] == sentinel).any():
        print(f"{col}: max={col_max}, replacing {sentinel} with NaN")
        data[col] = data[col].replace(sentinel, np.nan)

# Impute the 88888888 values
for col in cat_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

for col in num_cols:
    data[col] = data[col].fillna(data[col].mean())
# Out:
# AGEIMM: max=99, replacing 99 with -1
# ATTSCH: max=8, replacing 8 with NaN
# BEDRM: max=8, replacing 8 with NaN
# CFSTAT: max=8, replacing 8 with NaN
# CIP2021: max=88, replacing 88 with NaN
# CIP2021_STEM_SUM: max=88, replacing 88 with NaN
# CMA: max=999, replacing 999 with -1
# CONDO: max=8, replacing 8 with NaN
# COW: max=9, replacing 9 with -1
# COW: max=8, replacing 8 with NaN
# CfSize: max=8, replacing 8 with NaN
# CitOth: max=88, replacing 88 with NaN
# DIST: max=9, replacing 9 with -1
# DPGRSUM: max=88, replacing 88 with NaN
# DTYPE: max=8, replacing 8 with NaN
# EfSize: max=8, replacing 8 with NaN
# FPTWK: max=9, replacing 9 with -1
# GENSTAT: max=8, replacing 8 with NaN
# HCORENEED_IND: max=888, replacing 888 with NaN
# HDGREE: max=88, replacing 88 with NaN
# HHSIZE: max=8, replacing 8 with NaN
# HHTYPE: max=88, replacing 88 with NaN
# HLMOSTEN: max=8, replacing 8 with NaN
# HLMOSTFR: max=8, replacing 8 with NaN
# HLMOSTNO: max=88, replacing 88 with NaN
# HLREGEN: max=8, replacing 8 with NaN
# HLREGFR: max=8, replacing 8 with NaN
# IMMCAT5: max=88, replacing 88 with NaN
# IMMSTAT: max=88, replacing 88 with NaN
# JOBPERM: max=9, replacing 9 with -1
# JOBPERM: max=8, replacing 8 with NaN
# KOL: max=8, replacing 8 with NaN
# LFACT: max=88, replacing 88 with NaN
# LI_ELIG_OML_U18: max=9, replacing 9 with -1
# LOCSTUD: max=99, replacing 99 with -1
# LSTWRK: max=8, replacing 8 with NaN
# LWMOSTEN: max=9, replacing 9 with -1
# LWMOSTEN: max=8, replacing 8 with NaN
# LWMOSTFR: max=9, replacing 9 with -1
# LWMOSTFR: max=8, replacing 8 with NaN
# LWMOSTNO: max=9, replacing 9 with -1
# LWREGEN: max=9, replacing 9 with -1
# LWREGEN: max=8, replacing 8 with NaN
# LWREGFR: max=9, replacing 9 with -1
# LWREGFR: max=8, replacing 8 with NaN
# LWREGNO: max=9, replacing 9 with -1
# MODE: max=9, replacing 9 with -1
# MTNEn: max=8, replacing 8 with NaN
# MTNFr: max=8, replacing 8 with NaN
# MTNNO: max=88, replacing 88 with NaN
# MARSTH: max=8, replacing 8 with NaN
# Mob1: max=8, replacing 8 with NaN
# NAICS: max=999, replacing 999 with -1
# NAICS: max=888, replacing 888 with NaN
# NOC21: max=99, replacing 99 with -1
# NOC21: max=88, replacing 88 with NaN
# PKID25: max=9, replacing 9 with -1
# PKID25: max=8, replacing 8 with NaN
# PKID0_1: max=9, replacing 9 with -1
# PKID0_1: max=8, replacing 8 with NaN
# PKID15_24: max=9, replacing 9 with -1
# PKID15_24: max=8, replacing 8 with NaN
# PKID2_5: max=9, replacing 9 with -1
# PKID2_5: max=8, replacing 8 with NaN
# PKID6_14: max=9, replacing 9 with -1
# PKID6_14: max=8, replacing 8 with NaN
# PKIDS: max=9, replacing 9 with -1
# PKIDS: max=8, replacing 8 with NaN
# POB: max=88, replacing 88 with NaN
# POBPAR1: max=8, replacing 8 with NaN
# POBPAR2: max=8, replacing 8 with NaN
# POWST: max=9, replacing 9 with -1
# POWST: max=8, replacing 8 with NaN
# PR1: max=99, replacing 99 with -1
# PR1: max=88, replacing 88 with NaN
# PR5: max=99, replacing 99 with -1
# PRESMORTG: max=9, replacing 9 with -1
# PRESMORTG: max=8, replacing 8 with NaN
# PWDUR: max=9, replacing 9 with -1
# PWLEAVE: max=9, replacing 9 with -1
# PWOCC: max=9, replacing 9 with -1
# PWPR: max=99, replacing 99 with -1
# PWPR: max=88, replacing 88 with NaN
# RELIGION_DER: max=88, replacing 88 with NaN
# ROOM: max=88, replacing 88 with NaN
# SSGRAD: max=88, replacing 88 with NaN
# SUBSIDY: max=9, replacing 9 with -1
# SUBSIDY: max=8, replacing 8 with NaN
# TENUR: max=8, replacing 8 with NaN
# VISMIN: max=88, replacing 88 with NaN
# WKSWRK: max=9, replacing 9 with -1
# WKSWRK: max=8, replacing 8 with NaN
# WRKACT: max=88, replacing 88 with NaN
# YRIMM: max=9999, replacing 9999 with -1

# %%
data = data.copy()
data = data.assign(
    under30 = data['AGEGRP'] <= 9,
    thridgenorhigher = data['GENSTAT'] == 4,
    isacitizen = data['Citizen'] != 3,
    isreligious = data['RELIGION_DER'] == 22,
    Gender_Female = data['Gender'] == 1,
)

# %%
# get features and target
AGEGRP = data['AGEGRP'] # this serves as an example, you can choose other sensitive attributes
X = pd.get_dummies(data.drop(columns=["75k"]))
y = data["75k"]

# %% [markdown]
# ## Exploratory data analysis and feature engineering
# Inspect the data and do some plots that help you understand the dataset here.
#
# **Optional**: The dataset is already preprocessed. However, it might still pay off to invest some time in additional preprocessing here here (scaling, feature engineering, ...). This might improve model quality and help to rectify modeling errors.

# %% [markdown]
# **Note**: The data is imbalanced.

# %%
print(y.value_counts())
# Out:
# 75k
# 0    44476
# 1    12014
# Name: count, dtype: int64

# %% [markdown]
# ### Exploration of sensitive attributes
# ---
# Given the senstive attributes we have constructed 4 groups:
# 1. age under 30
# 2. third generation or higher
# 3. citizenship
# 4. Christian

# %%
import sweetviz as sv # pip install sweetviz

# fairness_vars = ['Gender', 'VISMIN', 'ABOID', 'AGEGRP', 'RELIGION_DER', 'MARSTH',
#                  'ETHDER', 'IMMSTAT', 'GENSTAT', 'POB', 'POBPAR1', 'POBPAR2', 'Citizen']

fairness_vars = ['AGEGRP', 'Gender', 'MARSTH', # demography
                 'Mob1', 'Mob5', #mobility
                 'ABOID', #indegenous population
                 'DPGRSUM', 'ETHDER', 'VISMIN', # ethnic or cultural origin
                 'RELIGION_DER', # religion
                 'FOL', #language
                 'GENSTAT', 'IMMSTAT', 'POB', 'POBPAR1', 'POBPAR2', 'Citizen', # place of birth
                 'HDGREE', # education
                 'COW', 'FPTWK', # labour market
                 'CfSize', # families and family compsition
                 'HHSIZE', 'PRIHM', #households
                 'PRESMORTG', 'Value', 'REPAIR', 'SUBSIDY', # Dwelling
                 'under30', 'thridgenorhigher', 'isacitizen', 'isreligious']

report = sv.analyze(X[fairness_vars])
report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(ie,e){&quot;use strict&quot;;var oe=[],r=Object.getPrototypeOf,ae=oe.slice,g=oe.flat?function(e){return oe.flat.call(e)}:function(e){return oe.concat.apply([],e)},s=oe.push,se=oe.indexOf,n={},i=n.toString,ue=n.hasOwnProperty,o=ue.toString,a=o.call(Object),le={},v=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},y=function(e){return null!=e&amp;&amp;e===e.window},C=ie.document,u={type:!0,src:!0,nonce:!0,noModule:!0};function m(e,t,n){var r,i,o=(n=n||C).createElement(&quot;script&quot;);if(o.text=e,t)for(r in u)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function x(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[i.call(e)]||&quot;object&quot;:typeof e}var t=&quot;3.7.1&quot;,l=/HTML$/i,ce=function(e,t){return new ce.fn.init(e,t)};function c(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=x(e);return!v(e)&amp;&amp;!y(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}function fe(e,t){return e.nodeName&amp;&amp;e.nodeName.toLowerCase()===t.toLowerCase()}ce.fn=ce.prototype={jquery:t,constructor:ce,length:0,toArray:function(){return ae.call(this)},get:function(e){return null==e?ae.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=ce.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return ce.each(this,e)},map:function(n){return this.pushStack(ce.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(ae.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(ce.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(ce.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:s,sort:oe.sort,splice:oe.splice},ce.extend=ce.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||v(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(ce.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||ce.isPlainObject(n)?n:{},i=!1,a[t]=ce.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},ce.extend({expando:&quot;jQuery&quot;+(t+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==i.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=ue.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;o.call(n)===a)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){m(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(c(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},text:function(e){var t,n=&quot;&quot;,r=0,i=e.nodeType;if(!i)while(t=e[r++])n+=ce.text(t);return 1===i||11===i?e.textContent:9===i?e.documentElement.textContent:3===i||4===i?e.nodeValue:n},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(c(Object(e))?ce.merge(n,&quot;string&quot;==typeo ...

# %%
sns.barplot(x='isreligious', y='75k', hue='thridgenorhigher', data=data)
# Out:
# <Axes: xlabel='isreligious', ylabel='75k'>

# %%
sns.barplot(x='under30', y='75k', hue='isacitizen', data=data)
# Out:
# <Axes: xlabel='under30', ylabel='75k'>

# %%
df_long = data.melt(
    id_vars=['75k', 'Gender_Female'],
    value_vars=['under30', 'thridgenorhigher', 'isacitizen', 'isreligious'],
    var_name='group',
    value_name='membership'
)
plt.figure(figsize=(6,5))

sns.barplot(
    data=df_long,
    x='group',
    y='75k',
    hue='membership',
)

plt.ylabel(r"$\mathbb{P}$(income >75K)")
plt.xlabel("Sensitive group")
plt.title("Income >75K across groups")
plt.xticks(rotation=45)
plt.legend(title="Membership")
plt.tight_layout()
plt.show()

# %%
g = sns.catplot(
    data=df_long,
    x='membership',
    y='75k',
    hue='Gender_Female',
    col='group',
    kind='bar',
    height=4,
    aspect=0.8,
    sharey=True
)

g.set_titles("{col_name}")
g.set_axis_labels("Group membership", r"$\mathbb{P}$(income >75K)")
plt.show()

# %%
results = []
for col in ['under30', 'thridgenorhigher', 'isacitizen', 'isreligious']:
    grouped = data.groupby([col, 'Gender_Female'])['75k'].mean().unstack()
    grouped['gap'] = grouped[False] - grouped[True]
    for val in grouped.index:
        results.append({ 'group': col, 'membership': val, 'gender_gap': grouped.loc[val, 'gap'] })
gap_df = pd.DataFrame(results)

g = sns.catplot(
    data=gap_df,
    x='membership',
    y='gender_gap',
    col='group',
    kind='bar',
    height=4,
    aspect=0.8,
    sharey=True
)

g.set_titles("{col_name}")
g.set_axis_labels("Membership", "Male - Female gap")

# add zero reference line per facet
for ax in g.axes.flat:
    ax.axhline(0, color='black', linewidth=1)

g.fig.suptitle("Gender income gap across subgroups", y=1.05)

plt.tight_layout()
plt.show()

# %%
groups = ['under30','thridgenorhigher','isacitizen','isreligious', 'Gender_Female']
for group in groups:
    print(f"Populationsize of {group} is {data[group].sum()/len(data)*100:.2f}%")
# Out:
# Populationsize of under30 is 37.47%
# Populationsize of thridgenorhigher is 45.37%
# Populationsize of isacitizen is 82.50%
# Populationsize of isreligious is 60.80%
# Populationsize of Gender_Female is 50.15%

# %%
# one-hot encoding all categorical features where the ordering is not telling
ordered = ["AGEGRP"]
cat_cols_to_encode = [col for col in cat_cols if col not in ordered]
X = pd.get_dummies(X, columns=cat_cols_to_encode)

# %% [markdown]
# ## Train test split
# We use stratification along the y feature to ensure that the training and the test set have a similar amount of positive and negative examples.
#
# **Do not change the random seed here to ensure that all groups have the same test set**

# %%
np.random.seed(42)  # set seed for consistent results
X_train, X_test, y_train, y_test, A_train, A_test = train_test_split(X, y, AGEGRP, random_state=42, stratify=y)

# %% [markdown]
# ## Fit Random Forest Model to Data
#
# Below we train a random forest estimator as blackbox model for our problem.
#
# **Note**: Hyperparameter tuning might take a while (especially when run online in Google Colab)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [300, 400, 500, 600],
    'max_depth': [10, 15, 20],
    'min_samples_leaf': [20, 30, 40, 50],
    'max_features': [1, 2, 3, 5],
    'class_weight': ['balanced']
}

# Create the GridSearchCV object
stratifier = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
                           param_grid=param_grid,
                           scoring='roc_auc',
                           n_jobs=-1,
                           cv = stratifier)

# Fit the grid search to the training data
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
rf = grid_search.best_estimator_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# %% [markdown]
# **Alternative**: Simply fit the model with the parameters found above

# %%
rf = RandomForestClassifier(n_estimators=600, max_depth=20, min_samples_leaf=20, max_features=5, class_weight='balanced', random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, max_features=5,
#                        min_samples_leaf=20, n_estimators=600, random_state=42)

# %% [markdown]
# ### Analyze fit of the model

# %%
def evaluate_model(model, X_test, y_test):
    # predict probabilities of readmission
    model.fit(X_train, y_train)
    y_pred = model.predict_proba(X_test)[:,1]

    auc = roc_auc_score(y_test, y_pred)
    print(f"{model} AUC: {auc:.4f}")

    # plot ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    plt.plot(fpr, tpr)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve Random Forest')
    plt.show()

    threshold = 0.5
    print(classification_report(y_test, y_pred > threshold))

    print(f" In a group of 1000 individuals approximately {sum(y_pred > threshold) / len(y_pred) * 1000:.0f} have a salary higher than 75k. Amongst these ... \n \
      \t ... {sum((y_test == 1) & (y_pred > threshold)) / len(y_pred) * 1000:.0f} are correctly classified; \n \
      \t ... {sum((y_test == 0) & (y_pred > threshold)) / len(y_pred) * 1000:.0f} are classified as not having a salary higher than 75k. \n \n \
      Additionally, we expect that there are {sum((y_test == 1) & (y_pred < threshold)) / len(y_pred) * 1000:.0f} individuals who have a salary higher than 75k but are not classified as such.")

# %%
evaluate_model(rf, X_test, y_test)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, max_features=5,
#                        min_samples_leaf=20, n_estimators=600, random_state=42) AUC: 0.9247
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88     11119
#            1       0.55      0.90      0.68      3004
#
#     accuracy                           0.82     14123
#    macro avg       0.76      0.85      0.78     14123
# weighted avg       0.88      0.82      0.84     14123
#
#  In a group of 1000 individuals approximately 347 have a salary higher than 75k. Amongst these ...
#        	 ... 191 are correctly classified;
#        	 ... 155 are classified as not having a salary higher than 75k.
#
#        Additionally, we expect that there are 21 individuals who have a salary higher than 75k but are not classified as such.

# %% [markdown]
# ### Using Lasso Regression as an interpretable model
# ---

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lasso = GridSearchCV(
    LogisticRegression(penalty='l1', solver='liblinear', random_state=42),
    param_grid={'C': [0.01, 0.1, 1.0, 10.0]},  # C = inverse of regularization strength
    cv=5, scoring='accuracy'
)
lasso.fit(X_train_scaled, y_train)
print(f"Lasso Tuned (best C={lasso.best_params_['C']}):")

# %% [markdown]
# **Alternative**: Simply fit the model with the parameters found above

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lasso = LogisticRegression(C=1 , penalty='l1', solver='liblinear', random_state=42)
lasso.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1, penalty='l1', random_state=42, solver='liblinear')

# %%
evaluate_model(lasso, X_test_scaled, y_test)
# Out:
# C:\Users\prabnoor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# LogisticRegression(C=1, penalty='l1', random_state=42, solver='liblinear') AUC: 0.9444
#               precision    recall  f1-score   support
#
#            0       1.00      0.45      0.62     11119
#            1       0.33      1.00      0.50      3004
#
#     accuracy                           0.57     14123
#    macro avg       0.66      0.73      0.56     14123
# weighted avg       0.86      0.57      0.60     14123
#
#  In a group of 1000 individuals approximately 643 have a salary higher than 75k. Amongst these ...
#        	 ... 212 are correctly classified;
#        	 ... 431 are classified as not having a salary higher than 75k.
#
#        Additionally, we expect that there are 0 individuals who have a salary higher than 75k but are not classified as such.

# %%
lasso_params = lasso.coef_
lasso_intercept = lasso.intercept_

feature_names = X_train.columns

lasso_coef_table = pd.DataFrame({
    "Feature": ["Intercept"] + list(feature_names),
    "Coefficient": [lasso.intercept_[0]] + list(lasso.coef_[0])
})

lasso_coef_table["Coefficient"] = lasso_coef_table["Coefficient"].round(3)
lasso_coef_table = lasso_coef_table.set_index("Feature")

lasso_coef_table.style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_f1102_row0_col0, #T_f1102_row2_col0, #T_f1102_row3_col0, #T_f1102_row4_col0, #T_f1102_row5_col0, #T_f1102_row6_col0, #T_f1102_row7_col0, #T_f1102_row8_col0, #T_f1102_row9_col0, #T_f1102_row10_col0, #T_f1102_row12_col0, #T_f1102_row13_col0, #T_f1102_row14_col0, #T_f1102_row16_col0, #T_f1102_row18_col0, #T_f1102_row20_col0, #T_f1102_row22_col0, #T_f1102_row23_col0, #T_f1102_row27_col0, #T_f1102_row37_col0, #T_f1102_row40_col0, #T_f1102_row41_col0, #T_f1102_row45_col0, #T_f1102_row47_col0, #T_f1102_row51_col0, #T_f1102_row53_col0, #T_f1102_row55_col0, #T_f1102_row56_col0, #T_f1102_row57_col0, #T_f1102_row59_col0, #T_f1102_row61_col0, #T_f1102_row62_col0, #T_f1102_row64_col0, #T_f1102_row65_col0, #T_f1102_row71_col0, #T_f1102_row72_col0, #T_f1102_row73_col0, #T_f1102_row75_col0, #T_f1102_row77_col0, #T_f1102_row79_col0, #T_f1102_row81_col0, #T_f1102_row82_col0, #T_f1102_row83_col0, #T_f1102_row88_col0, #T_f1102_row92_col0, #T_f1102_row96_col0, #T_f1102_row98_col0, #T_f1102_row101_col0, #T_f1102_row104_col0, #T_f1102_row107_col0, #T_f1102_row110_col0, #T_f1102_row111_col0, #T_f1102_row112_col0, #T_f1102_row113_col0, #T_f1102_row114_col0, #T_f1102_row115_col0, #T_f1102_row119_col0, #T_f1102_row120_col0, #T_f1102_row123_col0, #T_f1102_row126_col0, #T_f1102_row127_col0, #T_f1102_row128_col0, #T_f1102_row130_col0, #T_f1102_row131_col0, #T_f1102_row132_col0, #T_f1102_row134_col0, #T_f1102_row136_col0, #T_f1102_row141_col0, #T_f1102_row143_col0, #T_f1102_row145_col0, #T_f1102_row149_col0, #T_f1102_row150_col0, #T_f1102_row151_col0, #T_f1102_row152_col0, #T_f1102_row153_col0, #T_f1102_row154_col0, #T_f1102_row155_col0, #T_f1102_row156_col0, #T_f1102_row182_col0, #T_f1102_row183_col0, #T_f1102_row184_col0, #T_f1102_row185_col0, #T_f1102_row186_col0, #T_f1102_row187_col0, #T_f1102_row188_col0, #T_f1102_row190_col0, #T_f1102_row196_col0, #T_f1102_row197_col0, #T_f1102_row211_col0, #T_f1102_row214_col0, #T_f1102_row215_col0, #T_f1102_row216_col0, #T_f1102_row217_col0, #T_f1102_row218_col0, #T_f1102_row219_col0, #T_f1102_row220_col0, #T_f1102_row227_col0, #T_f1102_row228_col0, #T_f1102_row248_col0, #T_f1102_row256_col0, #T_f1102_row262_col0, #T_f1102_row263_col0, #T_f1102_row265_col0, #T_f1102_row266_col0, #T_f1102_row269_col0, #T_f1102_row271_col0, #T_f1102_row274_col0, #T_f1102_row276_col0, #T_f1102_row295_col0, #T_f1102_row299_col0, #T_f1102_row300_col0, #T_f1102_row302_col0, #T_f1102_row303_col0, #T_f1102_row306_col0, #T_f1102_row308_col0, #T_f1102_row309_col0, #T_f1102_row316_col0, #T_f1102_row322_col0, #T_f1102_row323_col0, #T_f1102_row324_col0, #T_f1102_row325_col0, #T_f1102_row329_col0, #T_f1102_row330_col0, #T_f1102_row332_col0, #T_f1102_row333_col0, #T_f1102_row336_col0, #T_f1102_row337_col0, #T_f1102_row338_col0, #T_f1102_row339_col0, #T_f1102_row340_col0, #T_f1102_row341_col0, #T_f1102_row344_col0, #T_f1102_row346_col0, #T_f1102_row351_col0, #T_f1102_row353_col0, #T_f1102_row354_col0, #T_f1102_row355_col0, #T_f1102_row356_col0, #T_f1102_row357_col0, #T_f1102_row358_col0, #T_f1102_row360_col0, #T_f1102_row361_col0, #T_f1102_row368_col0, #T_f1102_row369_col0, #T_f1102_row370_col0, #T_f1102_row376_col0, #T_f1102_row378_col0, #T_f1102_row382_col0, #T_f1102_row383_col0, #T_f1102_row385_col0, #T_f1102_row386_col0, #T_f1102_row389_col0, #T_f1102_row390_col0, #T_f1102_row391_col0, #T_f1102_row393_col0, #T_f1102_row397_col0, #T_f1102_row398_col0, #T_f1102_row400_col0, #T_f1102_row401_col0, #T_f1102_row404_col0, #T_f1102_row405_col0, #T_f1102_row407_col0, #T_f1102_row408_col0, #T_f1102_row409_col0, #T_f1102_row410_col0, #T_f1102_row413_col0, #T_f1102_row414_col0, #T_f1102_row418_col0, #T_f1102_row420_col0, #T_f1102_row423_col0, #T_f1102_row425_col0, #T_f1102_row427_col0, #T_f1102_row430_col0, #T_f1102_row431_col0, #T_f1102_row437_col0, #T_f1102_row438_col0, #T_f1102_row440_col0, #T_f1102_row441_col0, #T_f1102_row443_col0, #T_f1102_row444_col0, #T_f1102_row446_col0, #T_f1102_row448_col0, #T_f1102_row451_col0, #T_f1102_row455_col0, #T_f1102 ...
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_f1102_row1_col0, #T_f1102_row24_col0, #T_f1102_row33_col0, #T_f1102_row68_col0, #T_f1102_row76_col0, #T_f1102_row86_col0, #T_f1102_row116_col0, #T_f1102_row129_col0, #T_f1102_row206_col0, #T_f1102_row237_col0, #T_f1102_row279_col0, #T_f1102_row286_col0, #T_f1102_row296_col0, #T_f1102_row317_col0, #T_f1102_row334_col0, #T_f1102_row352_col0, #T_f1102_row367_col0, #T_f1102_row374_col0, #T_f1102_row377_col0, #T_f1102_row424_col0, #T_f1102_row434_col0, #T_f1102_row449_col0, #T_f1102_row453_col0, #T_f1102_row456_col0, #T_f1102_row476_col0, #T_f1102_row485_col0, #T_f1102_row490_col0, #T_f1102_row519_col0, #T_f1102_row565_col0, #T_

# %% [markdown]
# ### Using XGBoost as an blackbox model
# ---
# The Lasso achieving higher accuracy (0.92) than the RF (0.82) is unusual and can possibly be explained by the class imbalance: the RF uses class_weight='balanced' which sacrifices accuracy for recall, while Lasso does not. Hence, why RF scores better in recall.
# AUC is a better comparison metric here.
# Still, we add XGBoost as an alternative black-box to compare against.

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold

param_grid_xgb = {
    'n_estimators': [200, 300, 400],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.2],
}

stratifier = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_search_xgb = GridSearchCV(
    estimator=XGBClassifier(
        scale_pos_weight=(y_train == 0).sum() / (y_train == 1).sum(),
        random_state=42,
        eval_metric='logloss',
        verbosity=0
    ),
    param_grid=param_grid_xgb,
    scoring='roc_auc',
    cv=stratifier,
    n_jobs=-1,
)

grid_search_xgb.fit(X_train, y_train)

print(f"Best params: {grid_search_xgb.best_params_}")
xgb = grid_search_xgb.best_estimator_
# Out:
# Best params: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 400}

# %% [markdown]
# **Alternative**: Simply fit the model with the parameters found above

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    n_estimators=400,
    max_depth=6,
    learning_rate=0.1,
    scale_pos_weight=(y_train == 0).sum() / (y_train == 1).sum(),  # handles imbalance
    random_state=42,
    eval_metric='logloss',
    verbosity=0
)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
evaluate_model(xgb, X_test, y_test)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, ...) AUC: 0.9681
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94     11119
#            1       0.73      0.89      0.80      3004
#
#     accuracy                           0.91     14123
#    macro avg       0.85      0.90      0.87     14123
# weighted avg       0.92      0.91      0.91     14123
#
#  In a group of 1000 individuals approximately 258 have a salary higher than 75k. Amongst these ...
#        	 ... 189 are correctly classified;
#        	 ... 69 are classified as not having a salary higher than 75k.
#
#        Additionally, we expect that there are 23 individuals who have a salary higher than 75k but are not classified as such.

# %% [markdown]
# ### Exploration of fairness
# ---
# Given 4 groups we constructed, we look at these fairness measures:
# 1. Demographic Parity
# 2. True Positive Rate
# 3. False Positive Rate

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
sensitive_groups = {
    'under30': data['AGEGRP'] <= 9,
    'thirdgenorhigher': data['GENSTAT'] == 4,
    'isacitizen': data['Citizen'] != 3,
    'isreligious': data['RELIGION_DER'] != 22,  # not religious
    'Gender_Female': data['Gender'] == 1,
}

# %%
y_pred_rf = rf.predict(X_test)           # black-box random forest
y_pred_xgb = xgb.predict(X_test)         # black-box XGBoost
y_pred_lasso = lasso.predict(X_test_scaled)  # interpretable lasso

# Get the sensitive group values for test set
test_idx = X_test.index
sensitive_test = {k: v.loc[test_idx] for k, v in sensitive_groups.items()}
# Out:
# C:\Users\prabnoor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
def fairness_metrics(y_true, y_pred, group_mask):
    """Returns TPR, FPR, selection rate for a group vs complement."""
    results = {}
    for group_name, mask in group_mask.items():
        for group_val, label in [(True, group_name), (False, f'non_{group_name}')]:
            idx = mask == group_val
            if idx.sum() == 0:
                continue
            yt = y_true[idx]
            yp = y_pred[idx]
            tn, fp, fn, tp = confusion_matrix(yt, yp, labels=[0,1]).ravel()
            tpr = tp / (tp + fn) if (tp + fn) > 0 else 0  # equal opportunity
            fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  # predictive equality
            sr  = (tp + fp) / len(yp)                       # demographic parity
            results[label] = {'TPR': tpr, 'FPR': fpr, 'Selection Rate': sr, 'n': idx.sum()}
    return pd.DataFrame(results).T

# %%
metrics_rf    = fairness_metrics(y_test.values, y_pred_rf,    sensitive_test)
metrics_xgb   = fairness_metrics(y_test.values, y_pred_xgb,   sensitive_test)
metrics_lasso = fairness_metrics(y_test.values, y_pred_lasso, sensitive_test)

print("=== Random Forest ===")
print(metrics_rf.round(3))
print("\n=== XGBoost ===")
print(metrics_xgb.round(3))
print("\n=== Lasso ===")
print(metrics_lasso.round(3))
# Out:
# === Random Forest ===
#                         TPR    FPR  Selection Rate        n
# under30               0.696  0.065           0.103   5213.0
# non_under30           0.923  0.301           0.489   8910.0
# thirdgenorhigher      0.908  0.213           0.370   6422.0
# non_thirdgenorhigher  0.892  0.184           0.327   7701.0
# isacitizen            0.914  0.219           0.380  11599.0
# non_isacitizen        0.776  0.110           0.193   2524.0
# isreligious           0.885  0.179           0.318   5574.0
# non_isreligious       0.908  0.210           0.365   8549.0
# Gender_Female         0.876  0.181           0.287   7114.0
# non_Gender_Female     0.913  0.217           0.407   7009.0
#
# === XGBoost ===
#                         TPR    FPR  Selection Rate        n
# under30               0.757  0.020           0.064   5213.0
# non_under30           0.906  0.140           0.371   8910.0
# thirdgenorhigher      0.907  0.092           0.276   6422.0
# non_thirdgenorhigher  0.875  0.083           0.243   7701.0
# isacitizen            0.898  0.095           0.281  11599.0
# non_isacitizen        0.824  0.055           0.151   2524.0
# isreligious           0.863  0.078           0.233   5574.0
# non_isreligious       0.906  0.093           0.275   8549.0
# Gender_Female         0.845  0.068           0.187   7114.0
# non_Gender_Female     0.917  0.110           0.331   7009.0
#
# === Lasso ===
#                         TPR    FPR  Selection Rate        n
# under30               0.997  0.521           0.549   5213.0
# non_under30           0.999  0.568           0.698   8910.0
# thirdgenorhigher      0.999  0.563           0.661   6422.0
# non_thirdgenorhigher  0.999  0.534           0.628   7701.0
# isacitizen            0.999  0.584           0.680  11599.0
# non_isacitizen        0.997  0.398           0.472   2524.0
# isreligious           0.997  0.587           0.668   5574.0
# non_isreligious       0.999  0.520           0.627   8549.0
# Gender_Female         0.998  0.560           0.627   7114.0
# non_Gender_Female     0.999  0.532           0.660   7009.0

# %% [markdown]
# Demographic Parity (Selection Rate)

# %%
fig, axes = plt.subplots(1, 3, figsize=(21, 6), sharey=True)

for ax, (metrics, title) in zip(axes, [
    (metrics_rf, 'Random Forest'),
    (metrics_xgb, 'XGBoost'),
    (metrics_lasso, 'Lasso Logistic Regression')
]):
    metrics['Selection Rate'].plot(kind='barh', ax=ax, color='steelblue')
    ax.axvline(x=y_test.mean(), color='red', linestyle='--', label='Overall rate')
    ax.set_title(f'Demographic Parity — {title}')
    ax.set_xlabel('Selection Rate (P(ŷ=1))')
    ax.legend()

plt.tight_layout()
plt.savefig('demographic_parity.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# Equal Opportunity (TPR)

# %%
fig, axes = plt.subplots(1, 3, figsize=(21, 6), sharey=True)

for ax, (metrics, title) in zip(axes, [
    (metrics_rf, 'Random Forest'),
    (metrics_xgb, 'XGBoost'),
    (metrics_lasso, 'Lasso Logistic Regression')
]):
    metrics['TPR'].plot(kind='barh', ax=ax, color='darkorange')
    ax.set_title(f'Equal Opportunity (TPR) — {title}')
    ax.set_xlabel('True Positive Rate')

plt.tight_layout()
plt.savefig('equal_opportunity.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# Side-by-side comparison RF vs Lasso

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, metric in zip(axes, ['Selection Rate', 'TPR', 'FPR']):
    x = np.arange(len(metrics_rf))
    width = 0.25
    ax.bar(x - width, metrics_rf[metric],    width, label='Random Forest', color='steelblue')
    ax.bar(x,           metrics_xgb[metric],   width, label='XGBoost',      color='seagreen')
    ax.bar(x + width, metrics_lasso[metric], width, label='Lasso',         color='darkorange')
    ax.set_xticks(x)
    ax.set_xticklabels(metrics_rf.index, rotation=45, ha='right')
    ax.set_title(metric)
    ax.legend()

plt.suptitle('Fairness Metrics: RF vs Lasso', fontsize=14)
plt.tight_layout()
plt.savefig('fairness_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Conditional fairness analysis
# ---
# We will now look at fairness metrics conditioned on certain attributes.
#
# **Example:** how does age fairness differ specifically among women vs among men?

# %%
def conditional_fairness_metrics(y_true, y_pred, primary_mask, condition_mask, condition_name):
    """
    Computes fairness metrics for primary_mask groups, 
    separately for condition=True and condition=False subsets.
    """
    results = {}
    for cond_val, cond_label in [(True, f'({condition_name}=True)'), (False, f'({condition_name}=False)')]:
        cond_idx = condition_mask == cond_val
        for group_val, group_label in [(True, 'True'), (False, 'False')]:
            idx = (primary_mask == group_val) & cond_idx
            if idx.sum() < 30:  # skip very small groups
                continue
            yt = y_true[idx]
            yp = y_pred[idx]
            tn, fp, fn, tp = confusion_matrix(yt, yp, labels=[0,1]).ravel()
            tpr = tp / (tp + fn) if (tp + fn) > 0 else 0
            fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
            sr  = (tp + fp) / len(yp)
            label = f'primary={group_label} {cond_label}'
            results[label] = {'TPR': tpr, 'FPR': fpr, 'Selection Rate': sr, 'n': idx.sum()}
    return pd.DataFrame(results).T

# %%
# Condition 1: age group (under30 vs over30) conditioned on gender
print("=== Age fairness conditioned on Gender — Random Forest ===")
cond_age_gender_rf = conditional_fairness_metrics(
    y_test.values,
    y_pred_rf,
    sensitive_test['under30'],
    sensitive_test['Gender_Female'],
    'Gender_Female'
)
print(cond_age_gender_rf.round(3))

print("=== Age fairness conditioned on Gender — XGBoost ===")
cond_age_gender_xgb = conditional_fairness_metrics(
    y_test.values,
    y_pred_xgb,
    sensitive_test['under30'],
    sensitive_test['Gender_Female'],
    'Gender_Female'
)
print(cond_age_gender_xgb.round(3))

print("\n=== Age fairness conditioned on Gender — Lasso ===")
cond_age_gender_lasso = conditional_fairness_metrics(
    y_test.values,
    y_pred_lasso,
    sensitive_test['under30'],
    sensitive_test['Gender_Female'],
    'Gender_Female'
)
print(cond_age_gender_lasso.round(3))
# Out:
# === Age fairness conditioned on Gender — Random Forest ===
#                                        TPR    FPR  Selection Rate       n
# primary=True (Gender_Female=True)    0.663  0.061           0.085  2547.0
# primary=False (Gender_Female=True)   0.898  0.262           0.399  4567.0
# primary=True (Gender_Female=False)   0.712  0.068           0.120  2666.0
# primary=False (Gender_Female=False)  0.938  0.355           0.584  4343.0
# === Age fairness conditioned on Gender — XGBoost ===
#                                        TPR    FPR  Selection Rate       n
# primary=True (Gender_Female=True)    0.752  0.017           0.046  2547.0
# primary=False (Gender_Female=True)   0.854  0.103           0.265  4567.0
# primary=True (Gender_Female=False)   0.759  0.023           0.082  2666.0
# primary=False (Gender_Female=False)  0.936  0.191           0.484  4343.0
#
# === Age fairness conditioned on Gender — Lasso ===
#                                        TPR    FPR  Selection Rate       n
# primary=True (Gender_Female=True)    0.990  0.516           0.535  2547.0
# primary=False (Gender_Female=True)   0.999  0.590           0.678  4567.0
# primary=True (Gender_Female=False)   1.000  0.525           0.563  2666.0
# primary=False (Gender_Female=False)  0.999  0.539           0.719  4343.0

# %%
# Visualize conditional age fairness by gender
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

for ax, metric in zip(axes, ['Selection Rate', 'TPR', 'FPR']):
    x = np.arange(len(cond_age_gender_rf))
    width = 0.25
    ax.bar(x - width, cond_age_gender_rf[metric],    width, label='Random Forest', color='steelblue')
    ax.bar(x        , cond_age_gender_xgb[metric], width, label='XGBoost',         color='green')
    ax.bar(x + width, cond_age_gender_lasso[metric], width, label='Lasso',         color='darkorange')
    ax.set_xticks(x)
    ax.set_xticklabels(cond_age_gender_rf.index, rotation=30, ha='right', fontsize=8)
    ax.set_title(metric)
    ax.legend()

plt.suptitle('Age Fairness (under30) conditioned on Gender', fontsize=13)
plt.tight_layout()
plt.savefig('conditional_age_gender.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Condition 2: citizenship conditioned on age (under30)
print("=== Citizenship fairness conditioned on Age (under30) — Random Forest ===")
cond_cit_age_rf = conditional_fairness_metrics(
    y_test.values,
    y_pred_rf,
    sensitive_test['isacitizen'],
    sensitive_test['under30'],
    'under30'
)
print(cond_cit_age_rf.round(3))

print("=== Citizenship fairness conditioned on Age (under30) — XGBoost ===")
cond_cit_age_xgb = conditional_fairness_metrics(
    y_test.values,
    y_pred_xgb,
    sensitive_test['isacitizen'],
    sensitive_test['under30'],
    'under30'
)
print(cond_cit_age_xgb.round(3))

print("\n=== Citizenship fairness conditioned on Age (under30) — Lasso ===")
cond_cit_age_lasso = conditional_fairness_metrics(
    y_test.values,
    y_pred_lasso,
    sensitive_test['isacitizen'],
    sensitive_test['under30'],
    'under30'
)
print(cond_cit_age_lasso.round(3))
# Out:
# === Citizenship fairness conditioned on Age (under30) — Random Forest ===
#                                  TPR    FPR  Selection Rate       n
# primary=True (under30=True)    0.718  0.074           0.114  4178.0
# primary=False (under30=True)   0.588  0.028           0.056  1035.0
# primary=True (under30=False)   0.935  0.332           0.530  7421.0
# primary=False (under30=False)  0.813  0.176           0.288  1489.0
# === Citizenship fairness conditioned on Age (under30) — XGBoost ===
#                                  TPR    FPR  Selection Rate       n
# primary=True (under30=True)    0.748  0.021           0.067  4178.0
# primary=False (under30=True)   0.804  0.014           0.053  1035.0
# primary=True (under30=False)   0.914  0.153           0.402  7421.0
# primary=False (under30=False)  0.828  0.088           0.218  1489.0
#
# === Citizenship fairness conditioned on Age (under30) — Lasso ===
#                                  TPR    FPR  Selection Rate       n
# primary=True (under30=True)    1.000  0.575           0.602  4178.0
# primary=False (under30=True)   0.980  0.303           0.336  1035.0
# primary=True (under30=False)   0.999  0.591           0.724  7421.0
# primary=False (under30=False)  1.000  0.474           0.567  1489.0

# %%
# Summary heatmap of TPR across all conditional combinations
summary = pd.DataFrame({
    'Age|Female=T (RF)':   cond_age_gender_rf['TPR'],
    'Age|Female=T (XGBoost)': cond_age_gender_xgb['TPR'],
    'Age|Female=T (Lasso)': cond_age_gender_lasso['TPR'],
    'Citizen|Young=T (RF)': cond_cit_age_rf['TPR'],
    'Citizen|Young=T (XGBoost)': cond_cit_age_xgb['TPR'],
    'Citizen|Young=T (Lasso)': cond_cit_age_lasso['TPR'],
}).T

plt.figure(figsize=(12, 4))
sns.heatmap(summary, annot=True, fmt='.3f', cmap='RdYlGn', vmin=0.5, vmax=1.0)
plt.title('TPR Heatmap: Conditional Fairness Analysis')
plt.tight_layout()
plt.savefig('conditional_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
